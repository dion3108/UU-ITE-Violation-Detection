# %% [markdown]
# ## new line normalization

# %% [markdown]
# ## Lowercase normalization

# %% [markdown]
# ## LInk/Url normalization

# %% [markdown]
# link atau url diubah menjadi token seperti : [Url]

# %% [markdown]
# ## Mention Normalaization
